# %% [markdown]
# # Tạo File Word Toàn Diện
#
# Script này sẽ tạo file Word với nội dung đầy đủ từ project

# %%
import sys
from pathlib import Path

root = Path(r'c:\Users\HP\Music\classifies-students')
if str(root) not in sys.path:
    sys.path.insert(0, str(root))

from scripts.extend_word_to_40_pages import main

print('Dang bo sung noi dung dua tren do phu project...')
main()
print('Hoan thanh cap nhat file Word.')
